# %%
# ============================================================
#       EXPLORATORY DATA ANALYSIS - TITANIC DATASET
# ============================================================

# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set display and visualization options
pd.set_option('display.max_columns', None)
sns.set_style("whitegrid")

# ------------------------------------------------------------
# 1. LOAD TITANIC DATASET
# ------------------------------------------------------------

df = sns.load_dataset('titanic')

print("=" * 70)
print("EXPLORATORY DATA ANALYSIS - TITANIC DATASET")
print("=" * 70)

# ------------------------------------------------------------
# 2. DISPLAY FIRST FEW RECORDS
# ------------------------------------------------------------

print("\n1. FIRST 5 RECORDS")
print("-" * 50)
print(df.head())

# ------------------------------------------------------------
# 3. DISPLAY LAST FEW RECORDS
# ------------------------------------------------------------

print("\n2. LAST 5 RECORDS")
print("-" * 50)
print(df.tail())

# ------------------------------------------------------------
# 4. DATASET SHAPE
# ------------------------------------------------------------

print("\n3. DATASET SHAPE")
print("-" * 50)
print("Number of Rows    :", df.shape[0])
print("Number of Columns :", df.shape[1])

# ------------------------------------------------------------
# 5. COLUMN NAMES
# ------------------------------------------------------------

print("\n4. COLUMN NAMES")
print("-" * 50)
print(df.columns.tolist())

# ------------------------------------------------------------
# 6. DATA TYPES AND INFORMATION
# ------------------------------------------------------------

print("\n5. DATASET INFORMATION")
print("-" * 50)
df.info()

# ------------------------------------------------------------
# 7. STATISTICAL SUMMARY
# ------------------------------------------------------------

print("\n6. STATISTICAL SUMMARY")
print("-" * 50)
print(df.describe())

# ------------------------------------------------------------
# 8. CATEGORICAL DATA SUMMARY
# ------------------------------------------------------------

print("\n7. CATEGORICAL DATA SUMMARY")
print("-" * 50)
print(df.describe(include='object'))

# ------------------------------------------------------------
# 9. CHECK MISSING VALUES
# ------------------------------------------------------------

print("\n8. MISSING VALUES")
print("-" * 50)

missing = df.isnull().sum()
missing_percentage = (missing / len(df)) * 100

missing_table = pd.DataFrame({
    'Missing Values': missing,
    'Percentage': missing_percentage.round(2)
})

print(missing_table.sort_values(
    by='Missing Values',
    ascending=False
))

# ------------------------------------------------------------
# 10. CHECK DUPLICATE ROWS
# ------------------------------------------------------------

print("\n9. DUPLICATE ROWS")
print("-" * 50)
print("Number of duplicate rows:", df.duplicated().sum())

# ------------------------------------------------------------
# 11. SURVIVAL ANALYSIS
# ------------------------------------------------------------

print("\n10. SURVIVAL ANALYSIS")
print("-" * 50)

print("\nSurvival Counts:")
print(df['survived'].value_counts())

print("\nSurvival Percentage:")
print((df['survived'].value_counts(normalize=True) * 100).round(2))

# Visualization
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x='survived')
plt.title('24eu02039 Survival Count')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Number of Passengers')
plt.show()

# ------------------------------------------------------------
# 12. GENDER ANALYSIS
# ------------------------------------------------------------

print("\n11. GENDER ANALYSIS")
print("-" * 50)

print("Number of passengers by gender:")
print(df['sex'].value_counts())

print("\nSurvival rate by gender:")
print((df.groupby('sex')['survived'].mean() * 100).round(2))

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='sex', hue='survived')
plt.title('24eu02039 Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# ------------------------------------------------------------
# 13. PASSENGER CLASS ANALYSIS
# ------------------------------------------------------------

print("\n12. PASSENGER CLASS ANALYSIS")
print("-" * 50)

print("Passengers in each class:")
print(df['pclass'].value_counts().sort_index())

print("\nSurvival rate by passenger class:")
print((df.groupby('pclass')['survived'].mean() * 100).round(2))

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='pclass', hue='survived')
plt.title('24eu02039 Survival by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.show()

# ------------------------------------------------------------
# 14. AGE ANALYSIS
# ------------------------------------------------------------

print("\n13. AGE ANALYSIS")
print("-" * 50)

print("Average Age:", round(df['age'].mean(), 2))
print("Minimum Age:", df['age'].min())
print("Maximum Age:", df['age'].max())

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', bins=30, kde=True)
plt.title('24eu02039 Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Age vs Survival
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='survived', y='age')
plt.title('24eu02039 Age Distribution by Survival')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Age')
plt.show()

# ------------------------------------------------------------
# 15. FARE ANALYSIS
# ------------------------------------------------------------

print("\n14. FARE ANALYSIS")
print("-" * 50)

print("Average Fare:", round(df['fare'].mean(), 2))
print("Minimum Fare:", df['fare'].min())
print("Maximum Fare:", df['fare'].max())

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='fare', bins=30, kde=True)
plt.title('24eu02039 Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# Fare by passenger class
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='pclass', y='fare')
plt.title('24eu02039 Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# ------------------------------------------------------------
# 16. EMBARKATION ANALYSIS
# ------------------------------------------------------------

print("\n15. EMBARKATION ANALYSIS")
print("-" * 50)

print("Passengers by embarkation port:")
print(df['embarked'].value_counts())

print("\nSurvival rate by embarkation port:")
print((df.groupby('embarked')['survived'].mean() * 100).round(2))

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='embarked', hue='survived')
plt.title('24eu02039 Survival by Embarkation Port')
plt.xlabel('Embarkation Port')
plt.ylabel('Number of Passengers')
plt.show()

# ------------------------------------------------------------
# 17. FAMILY SIZE ANALYSIS
# ------------------------------------------------------------

df['family_size'] = df['sibsp'] + df['parch'] + 1

print("\n16. FAMILY SIZE ANALYSIS")
print("-" * 50)

print(df['family_size'].value_counts().sort_index())

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='family_size')
plt.title('24eu02039 Family Size Distribution')
plt.xlabel('Family Size')
plt.ylabel('Number of Passengers')
plt.show()

print("\nSurvival rate by family size:")
print((df.groupby('family_size')['survived'].mean() * 100).round(2))

plt.figure(figsize=(12, 6))
sns.barplot(
    data=df,
    x='family_size',
    y='survived'
)
plt.title('24eu02039 Survival Rate by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')
plt.show()

# ------------------------------------------------------------
# 18. GENDER + CLASS + SURVIVAL
# ------------------------------------------------------------

print("\n17. SURVIVAL BY GENDER AND CLASS")
print("-" * 50)

print(
    (df.groupby(['pclass', 'sex'])['survived'].mean() * 100)
    .round(2)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=df,
    x='pclass',
    y='survived',
    hue='sex'
)
plt.title('24eu02039 Survival Rate by Class and Gender')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# ------------------------------------------------------------
# 19. CORRELATION HEATMAP
# ------------------------------------------------------------

print("\n18. CORRELATION MATRIX")
print("-" * 50)

numeric_df = df.select_dtypes(include=np.number)
correlation = numeric_df.corr()

print(correlation.round(2))

plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)
plt.title('24eu02039 Correlation Heatmap')
plt.show()

# ------------------------------------------------------------
# 20. OUTLIER DETECTION
# ------------------------------------------------------------

print("\n19. OUTLIER DETECTION")
print("-" * 50)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(y=df['age'])
plt.title('24eu02039 Age - Outliers')

plt.subplot(1, 2, 2)
sns.boxplot(y=df['fare'])
plt.title('Fare - Outliers')

plt.tight_layout()
plt.show()

# ------------------------------------------------------------
# 21. PAIRPLOT
# ------------------------------------------------------------

print("\n20. PAIRPLOT")

sns.pairplot(
    df[['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']],
    hue='survived'
)
plt.show()

# ------------------------------------------------------------
# 22. FINAL SUMMARY
# ------------------------------------------------------------

print("\n")
print("=" * 70)
print("                         FINAL SUMMARY")
print("=" * 70)

print("\nDataset:")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nOverall Survival Rate:")
print(round(df['survived'].mean() * 100, 2), "%")

print("\nSurvival Rate by Gender:")
print((df.groupby('sex')['survived'].mean() * 100).round(2))

print("\nSurvival Rate by Class:")
print((df.groupby('pclass')['survived'].mean() * 100).round(2))

print("\nAverage Age:")
print(round(df['age'].mean(), 2))

print("\nAverage Fare:")
print(round(df['fare'].mean(), 2))

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

# ------------------------------------------------------------
# 23. EDA CONCLUSIONS
# ------------------------------------------------------------

print("\n")
print("=" * 70)
print("                         CONCLUSIONS")
print("=" * 70)

print("""
1. The Titanic dataset contains passenger information such as
   age, gender, passenger class, fare, family members and survival.

2. The dataset contains missing values, especially in the age,
   deck and embarked columns.

3. Female passengers had a considerably higher survival rate
   than male passengers.

4. Passengers from higher classes generally had higher survival
   rates than passengers from lower classes.

5. Age is distributed across a wide range, with many passengers
   being young and middle-aged.

6. First-class passengers generally paid higher fares than
   second- and third-class passengers.

7. Fare and passenger class have a strong relationship.

8. Family size is associated with different survival patterns.

9. The correlation heatmap shows relationships between the
   numerical variables.

10. Overall, gender and passenger class are important factors
    associated with survival in the Titanic dataset.
""")

print("=" * 70)
print("             TITANIC EDA COMPLETED SUCCESSFULLY")
print("=" * 70)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS - TITANIC DATASET
# ...
#
# 1. FIRST 5 RECORDS
# --------------------------------------------------
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# 2. LAST 5 RECORDS
# --------------------------------------------------
# ...
